# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
cd ml-thing
# Out:
# /content/gdrive/MyDrive/ml-thing

# %%
#import stuff
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
import pickle
from tensorflow.keras.callbacks import TensorBoard
import tensorflow as tf
import time
from sklearn.utils import shuffle

# %%
#import data
pickle_in = open("X.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("Y.pickle","rb")
Y = pickle.load(pickle_in)

X = np.array(X)
Y = np.array(Y)

print(X[0])

#shuffle data
X, Y = shuffle(X, Y, random_state=0)

print(X.shape)
# Out:
# [[0.0078125  0.0078125  0.01171875 ... 0.12109375 0.1171875  0.1015625 ]
#  [0.01171875 0.00390625 0.00390625 ... 0.11328125 0.125      0.09765625]
#  [0.015625   0.         0.         ... 0.12109375 0.1171875  0.0859375 ]
#  ...
#  [0.15234375 0.16015625 0.18359375 ... 0.         0.         0.        ]
#  [0.1484375  0.16796875 0.18359375 ... 0.         0.         0.        ]
#  [0.1484375  0.17578125 0.19921875 ... 0.         0.         0.        ]]
# (1021, 300, 300)

# %%
input_shape = (300, 300, 1)
dense_layers = [2]
layer_sizes = [64]
conv_layers = [2]

batch_size = 100
epochs = 40



for dense_layer in dense_layers:
  for layer_size in layer_sizes:
    for conv_layer in conv_layers:
      NAME = "{}-conv-{}-nodes-{}-dense-{}".format(conv_layer, layer_size, dense_layer, int(time.time()))
      print(NAME)
      # tensorboard = TensorBoard(log_dir="final-logs/{}".format(NAME))
      # stopping = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5)

      model = keras.Sequential()

      #conv layers
      model.add(layers.Conv2D(layer_size, (3, 3), input_shape=input_shape))
      model.add(layers.Activation('relu'))
      model.add(layers.MaxPooling2D(pool_size=(2, 2)))

      for i in range(conv_layer-1):
        model.add(layers.Conv2D(layer_size, (3, 3),strides=(3, 3)))
        model.add(layers.Activation('relu'))
        model.add(layers.MaxPooling2D(pool_size=(2, 2)))

      #dense layers
      model.add(layers.Flatten()) 
      for j in range(dense_layer):
        model.add(layers.Dense(layer_size, activation="relu"))

        

      #output layer
      model.add(layers.Dense(1, activation="sigmoid"))


      model.summary()
      model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
      # model.fit(X, Y, batch_size=batch_size, epochs=epochs, validation_split=0.3,callbacks=[stopping,tensorboard])
      model.fit(X, Y, batch_size=batch_size, epochs=epochs, validation_split=0.3)


      model.save("final/" + NAME + ".model")
# Out:
# 2-conv-64-nodes-2-dense-1681819876
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 298, 298, 64)      640
#
#  activation (Activation)     (None, 298, 298, 64)      0
#
#  max_pooling2d (MaxPooling2D  (None, 149, 149, 64)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 49, 49, 64)        36928
#
#  activation_1 (Activation)   (None, 49, 49, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 24, 24, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 36864)             0
#
#  dense (Dense)               (None, 64)                2359360
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 2,401,153
# Trainable params: 2,401,153
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 8/8 [==============================] - 14s 289ms/step - loss: 0.6965 - accuracy: 0.5126 - val_loss: 0.6768 - val_accuracy: 0.5016
# Epoch 2/40
# 8/8 [==============================] - 1s 180ms/step - loss: 0.6557 - accuracy: 0.5924 - val_loss: 0.6132 - val_accuracy: 0.6319
# Epoch 3/40
# 8/8 [==============================] - 1s 181ms/step - loss: 0.5550 - accuracy: 0.7549 - val_loss: 0.4177 - val_accuracy: 0.8469
# Epoch 4/40
# 8/8 [==============================] - 1s 182ms/step - loss: 0.4210 - accuracy: 0.8109 - val_loss: 0.3788 - val_accuracy: 0.8241
# Epoch 5/40
# 8/8 [==============================] - 2s 202ms/step - loss: 0.3362 - accuracy: 0.8515 - val_loss: 0.2781 - val_accuracy: 0.8730
# Epoch 6/40
# 8/8 [==============================] - 2s 203ms/step - loss: 0.2738 - accuracy: 0.8992 - val_loss: 0.4154 - val_accuracy: 0.8111
# Epoch 7/40
# 8/8 [==============================] - 2s 199ms/step - loss: 0.3000 - accuracy: 0.8739 - val_loss: 0.3100 - val_accuracy: 0.8664
# Epoch 8/40
# 8/8 [==============================] - 2s 199ms/step - loss: 0.2335 - accuracy: 0.9202 - val_loss: 0.2697 - val_accuracy: 0.8730
# Epoch 9/40
# 8/8 [==============================] - 2s 201ms/step - loss: 0.1912 - accuracy: 0.9300 - val_loss: 0.1774 - val_accuracy: 0.9349
# Epoch 10/40
# 8/8 [==============================] - 1s 182ms/step - loss: 0.1986 - accuracy: 0.9272 - val_loss: 0.3000 - val_accuracy: 0.8664
# Epoch 11/40
# 8/8 [==============================] - 2s 201ms/step - loss: 0.1928 - accuracy: 0.9202 - val_loss: 0.3244 - val_accuracy: 0.8534
# Epoch 12/40
# 8/8 [==============================] - 1s 182ms/step - loss: 0.1929 - accuracy: 0.9272 - val_loss: 0.2697 - val_accuracy: 0.8827
# Epoch 13/40
# 8/8 [==============================] - 2s 201ms/step - loss: 0.1710 - accuracy: 0.9286 - val_loss: 0.2419 - val_accuracy: 0.8958
# Epoch 14/40
# 8/8 [==============================] - 2s 203ms/step - loss: 0.1353 - accuracy: 0.9538 - val_loss: 0.1742 - val_accuracy: 0.9251
# Epoch 15/40
# 8/8 [==============================] - 1s 186ms/step - loss: 0.1235 - accuracy: 0.9538 - val_loss: 0.2720 - val_accuracy: 0.8860
# Epoch 16/40
# 8/8 [==============================] - 2s 199ms/step - loss: 0.1195 - accuracy: 0.9524 - val_loss: 0.1685 - val_accuracy: 0.9349
# Epoch 17/40
# 8/8 [==============================] - 2s 203ms/step - loss: 0.1066 - accuracy: 0.9664 - val_loss: 0.2042 - val_accuracy: 0.9251
# Epoch 18/40
# 8/8 [==============================] - 2s 203ms/step - loss: 0.1312 - accuracy: 0.9482 - val_loss: 0.2032 - val_accuracy: 0.9153
# Epoch 19/40
# 8/8 [==============================] - 1s 181ms/step - loss: 0.0887 - accuracy: 0.9804 - val_loss: 0.1814 - val_accuracy: 0.9218
# Epoch 20/40
# 8/8 [==============================] - 1s 183ms/step - loss: 0.0771 - accuracy: 0.9706 - val_loss: 0.2000 - val_accuracy: 0.9218
# Epoch 21/40
# 8/8 [==============================] - 1s 182ms/step - loss: 0.0581 - accuracy: 0.9860 - val_loss: 0.1832 - val_accuracy: 0.9381
# Epoch 22/40
# 8/8 [==============================] - 1s 183ms/step - loss: 0.0769 - accuracy: 0.9720 - val_loss: 0.1807 - val_accuracy: 0.9251
# Epoch 23/40
# 8/8 [==============================] - 1s 180ms/step - loss: 0.1049 - accuracy: 0.9608 - val_loss: 0.2030 - val_accuracy: 0.9186
# Epoch 24/40
# 8/8 [==============================] - 2s 205ms/step - loss: 0.0700 - accuracy: 0.9804 - val_loss: 0.2126 - val_accuracy: 0.9186
# Epoch 25/40
# 8/8 [==============================] - 2s 197ms/step - loss: 0.0488 - accuracy: 0.9860 - val_loss: 0.2028 - val_accuracy: 0.9153
# Epoch 26/40
# 8/8 [==============================] - 2s 211ms/step - loss: 0.0399 - accuracy: 0.9874 - val_loss: 0.2432 - val_accuracy: 0.9218
# Epoch 27/40
# 8/8 [==============================] - 2s 201ms/step - loss: 0.0463 - accuracy: 0.9846 - val_loss: 0.2065 - val_accuracy: 0.9186
# Epoch 28/40
# 8/8 [==============================] - 1s 182ms/step - loss: 0.0382 - accuracy: 0.9916 - val_loss: 0.2263 - val_accuracy: 0.9153
# Epoch 29/40
# 8/8 [==============================] - 1s 183ms/step - loss: 0.0227 - accuracy: 0.9958 - val_loss: 0.2267 - val_accuracy: 0.9121
# Epoch 30/40
# 8/8 [==============================] - 2s 201ms/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.2514 - val_accuracy: 0.9153
# Epoch 31/40
# 8/8 [==============================] - 1s 182ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.2503 - val_accuracy: 0.9186
# Epoch 32/40
# 8/8 [==============================] - 1s 183ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.2610 - val_accuracy: 0.9186
# Epoch 33/40
# 8/8 [==============================] - 2s 211ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.2281 - val_accuracy: 0.9349
# Epoch 34/40
# 8/8 [==============================] - 2s 214ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.2329 - val_accuracy: 0.9316
# Epoch 35/40
# 8/8 [==============================] - 2s 188ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.3958 - val_accuracy: 0.8893
# Epoch 36/40
# 8/8 [==============================] - 1s 184ms/step - loss: 0.0112 - accuracy: 0.9972 - val_loss: 0.2238 - val_accuracy: 0.9283
# Epoch 37/40
# 8/8 [==============================] - 2s 202ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.2443 - val_accuracy: 0.9251
# Epoch 38/40
# 8/8 [==============================] - 2s 202ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.2628 - val_accuracy: 0.9218
# Epoch 39/40
# 8/8 [==============================] - 1s 183ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.2662 - val_accuracy: 0.9283
# Epoch 40/40
# 8/8 [==============================] - 2s 203ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.2683 - val_accuracy: 0.9251
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.
